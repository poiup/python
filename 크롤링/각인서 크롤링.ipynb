# %%
import requests # selenium과 달리 내장되어 있어서 따로 설치할 필요가 없음
from bs4 import BeautifulSoup # 웹에서 가져온 데이터를 정제하는 역할
import time # 코드중간에 딜레이를 넣는 역할
import codecs # 코덱스

# %%
#로아 마켓 접속
res = requests.get("https://lostark.game.onstove.com/Market")
# 2.받아온 변수 res.text를하면 해당 페이지의 소스코드가 나옵니다
source = res.text
source
# Out:
# '<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" lang="ko" xml:lang="ko">\n<head>\n\t<title>STOVE</title>\n\n\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\t<meta http-equiv="Content-Script-Type" content="text/javascript" />\n\t<meta http-equiv="Content-Style-Type" content="text/css" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n\t<meta name="viewport" content="width=542">\n\t<link rel="icon" href="https://member.onstove.com/static/image/favicon.ico?201604051600">\n\n\t<!-- script -->\n\t<script type="text/javascript" src="https://member.onstove.com/static/js/jquery-1.11.1.min.js?201604051600"></script>\n\t<script type="text/javascript" src="https://member.onstove.com/static/js/jquery.easing.1.3.js?201604051600"></script>\n\t<script type="text/javascript" src="https://member.onstove.com/static/js/html5.js?201604051600"></script><!-- ie7 , ie8 html5 support -->\n\t<script type="text/javascript" src="https://member.onstove.com/static/js/smilegate.js?201604051600"></script>\n\t<script type="text/javascript" src="https://member.onstove.com/static/js/smilegate.ui.js?201806250000"></script>\n\t<script type="text/javascript" src="https://member.onstove.com/static/js/json2.js?201604051600"></script>\n\n\t<script type="text/javascript" src=" //d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/js/share/jquery.scrollbar/jquery.scrollbar.min.js"></script>\n\t<script type="text/javascript" src="//d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/js/share/new_ui.js"></script>\n\t<script type="text/javascript" src=" //d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/js/ui.base.js"></script>\n\t<script type="text/javascript" src="//d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/js/ui.scroll.js"></script>\n\t<!-- stylesheet -->\n\t<link rel="stylesheet" href=" //d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/js/share/jquery.scrollbar/jquery.scrollbar.css" >\n\n\n\t<link rel="stylesheet" href="//d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/layouts/NotoSansCJK-KR.css" />\n\t<link rel="stylesheet" href=" //d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/modules/skip-nav.css">\n\t<link rel="stylesheet" href="//d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/layouts/layout.css">\n\t<link rel="stylesheet" href=" //d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/layouts/global.css">\n\t<link rel="stylesheet" href="//d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/layouts/base.css">\n\n\t<link rel="stylesheet" href=" //d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/modules/dialog.css">\n\t<link rel="stylesheet" href="//d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/modules/list.css">\n\t<link rel="stylesheet" href=" //d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/elements/select.css">\n\t<link rel="stylesheet" href="//d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/elements/btn.css">\n\t<link rel="stylesheet" href=" //d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/elements/radio.css">\n\t<link rel="stylesheet" href="//d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/elements/checkbox.css">\n\t<link rel="stylesheet" href=" //d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/elements/input.css">\n\t<link rel="stylesheet" href="//d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/elements/icon.css">\n\t<link rel="stylesheet" href=" //d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/modules/guide.css">\n\t<link rel="stylesheet" href="//d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/modules/panel.css">\n\t<link rel="stylesheet" href=" //d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/modules/alerts.css">\n\t<link rel="stylesheet" href="//d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/modules/tab.css">\n\t<link rel="stylesheet" href=" //d2h5doj4xlbun0.cloudfront.net/member-0.0.1459/static/css/modules/form.css">\n\t<link rel="stylesheet" href="//d2h ...
